# %% [markdown]
# ## Simple but effective collaborative filtering recommendation system by anime-similarity

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/anime-recommendations-database/rating.csv
# /kaggle/input/anime-recommendations-database/anime.csv

# %% [markdown]
# # Data importation

# %%
dirname = '/kaggle/input/anime-recommendations-database'

rating_path = os.path.join(dirname, 'rating.csv')
anime_path = os.path.join(dirname, 'anime.csv')

rating_df = pd.read_csv(rating_path)
item_df = pd.read_csv(anime_path)

# %%
print(rating_df.shape)
print(rating_df.head())
# Out:
# (7813737, 3)
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
print(item_df.shape)
print(item_df.head())
# Out:
# (12294, 7)
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
rating_df.isna().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %% [markdown]
# We don't have NA on rating_df! Good point.
#
# # Data preparation
#
# Let's rename the anime_id by item_id. From now, the "animes" will be called "items".

# %%
colname_mapping = {
    'anime_id': 'item_id'
}
rating_df = rating_df.rename(columns=colname_mapping)
item_df = item_df.rename(columns=colname_mapping)

# %%
print(rating_df.head())
print(item_df.head())
# Out:
#    user_id  item_id  rating
# 0        1       20      -1
# 1        1       24      -1
# 2        1       79      -1
# 3        1      226      -1
# 4        1      241      -1
#    item_id                              name  \
# 0    32281                    Kimi no Na wa.
# 1     5114  Fullmetal Alchemist: Brotherhood
# 2    28977                          Gintama°
# 3     9253                       Steins;Gate
# 4     9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
train = rating_df

# %% [markdown]
# # Model definition and fitting

# %%
from implicit import nearest_neighbours as nn
import scipy.sparse as sparse

# %%
sparse_item_user = sparse.csr_matrix(
    (train['rating'].astype(float),
     (train['item_id'], train['user_id'])))

model = nn.CosineRecommender()

# Calculate the confidence by multiplying it by our alpha value.
alpha_val = 15
data_conf = (sparse_item_user * alpha_val).astype('double')
model.fit(data_conf)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=34520.0), HTML(value='')))

# %%
items_id = train.item_id.unique().tolist()
items_id[:5]
# Out:
# [20, 24, 79, 226, 241]

# %% [markdown]
# # Item-similarity dict creation

# %%
def create_item_id_to_similar(model, nb_reco, factor_similar, items_id):
    return {item_id: [(sim_item_id, sim_score)
                      for sim_item_id, sim_score in model.similar_items(
                          item_id, nb_reco * factor_similar)
                      if sim_item_id != item_id
                     ]
            for item_id in items_id
           }

item_id_to_similar = create_item_id_to_similar(
    model=model,
    nb_reco=10,
    factor_similar=5,
    items_id=items_id)

# %%
list(item_id_to_similar.items())[:2]
# Out:
# [(20,
#   [(1535, 0.5463407077066675),
#    (121, 0.47272149158167476),
#    (269, 0.466974610783123),
#    (5114, 0.4644807583399425),
#    (1575, 0.46391151405222386),
#    (11757, 0.46328649033916763),
#    (16498, 0.45781777902012366),
#    (813, 0.452006430364823),
#    (442, 0.4444997099847257),
#    (9919, 0.4439122675141474),
#    (2904, 0.44365494125697846),
#    (226, 0.4357369321904798),
#    (2472, 0.4343306763730486),
#    (3588, 0.432832107642108),
#    (8074, 0.4324508320250583),
#    (223, 0.41795363534614516),
#    (936, 0.41118621378998754),
#    (6702, 0.4084388192008567),
#    (4437, 0.4065098938344902)]),
#  (24,
#   [(846, 0.8247128890929168),
#    (517, 0.5924375328243505),
#    (4015, 0.5562273803416666),
#    (72, 0.38335837369811243),
#    (849, 0.37472112119618595),
#    (71, 0.37233760843976127),
#    (189, 0.35264547278487807),
#    (73, 0.3453509503193189),
#    (245, 0.33648511961634203),
#    (2104, 0.3334990346845112),
#    (66, 0.32871673370836213),
#    (4224, 0.32718830479054095),
#    (1887, 0.3259372703781951),
#    (2167, 0.32274845611576625),
#    (59, 0.3200087242978359),
#    (1210, 0.31944127459442767),
#    (355, 0.3161241477305688),
#    (240, 0.31511034749069516),
#    (330, 0.31264509651828154)])]

# %% [markdown]
# # Computation and visualization functions definition

# %%
# visualize similar anime
max_item = 3

def print_item_features(item_id):
    current_item = item_df[item_df['item_id'] == item_id]
    print(f"id: {item_id}\nname: {current_item['name'].values[0]}\ngenre: {current_item['genre'].values[0]}")

for item_id, sim_item_ids in list(item_id_to_similar.items())[:max_item]:
    print("-----------------------------------------------")
    print_item_features(item_id=item_id)
    print("-----------------------------------------------")
    sim_item_ids = [id[0] for id in sim_item_ids]
    for counter, sim_item_id in enumerate(sim_item_ids):
        print(f"similarity rank {counter+1}")
        print_item_features(item_id=sim_item_id)
    print("-----------------------------------------------")
# Out:
# -----------------------------------------------
# id: 20
# name: Naruto
# genre: Action, Comedy, Martial Arts, Shounen, Super Power
# -----------------------------------------------
# similarity rank 1
# id: 1535
# name: Death Note
# genre: Mystery, Police, Psychological, Supernatural, Thriller
# similarity rank 2
# id: 121
# name: Fullmetal Alchemist
# genre: Action, Adventure, Comedy, Drama, Fantasy, Magic, Military, Shounen
# similarity rank 3
# id: 269
# name: Bleach
# genre: Action, Comedy, Shounen, Super Power, Supernatural
# similarity rank 4
# id: 5114
# name: Fullmetal Alchemist: Brotherhood
# genre: Action, Adventure, Drama, Fantasy, Magic, Military, Shounen
# similarity rank 5
# id: 1575
# name: Code Geass: Hangyaku no Lelouch
# genre: Action, Mecha, Military, School, Sci-Fi, Super Power
# similarity rank 6
# id: 11757
# name: Sword Art Online
# genre: Action, Adventure, Fantasy, Game, Romance
# similarity rank 7
# id: 16498
# name: Shingeki no Kyojin
# genre: Action, Drama, Fantasy, Shounen, Super Power
# similarity rank 8
# id: 813
# name: Dragon Ball Z
# genre: Action, Adventure, Comedy, Fantasy, Martial Arts, Shounen, Super Power
# similarity rank 9
# id: 442
# name: Naruto Movie 1: Dai Katsugeki!! Yuki Hime Shinobu Houjou Dattebayo!
# genre: Adventure, Comedy, Drama, Historical, Shounen, Supernatural
# similarity rank 10
# id: 9919
# name: Ao no Exorcist
# genre: Action, Demons, Fantasy, Shounen, Supernatural
# similarity rank 11
# id: 2904
# name: Code Geass: Hangyaku no Lelouch R2
# genre: Action, Drama, Mecha, Military, Sci-Fi, Super Power
# similarity rank 12
# id: 226
# name: Elfen Lied
# genre: Action, Drama, Horror, Psychological, Romance, Seinen, Supernatural
# similarity rank 13
# id: 2472
# name: Naruto: Shippuuden Movie 1
# genre: Action, Adventure, Comedy, Fantasy, Shounen
# similarity rank 14
# id: 3588
# name: Soul Eater
# genre: Action, Adventure, Comedy, Fantasy, Shounen, Supernatural
# similarity rank 15
# id: 8074
# name: Highschool of the Dead
# genre: Action, Ecchi, Horror, Supernatural
# similarity rank 16
# id: 223
# name: Dragon Ball
# genre: Adventure, Comedy, Fantasy, Martial Arts, Shounen, Super Power
# similarity rank 17
# id: 936
# name: Naruto Movie 2: Dai Gekitotsu! Maboroshi no Chiteiiseki Dattebayo!
# genre: Adventure, Comedy, Drama, Fantasy, Shounen, Supernatural
# similarity rank 18
# id: 6702
# name: Fairy Tail
# genre: Action, Adventure, Comedy, Fantasy, Magic, Shounen
# similarity rank 19
# id: 4437
# name: Naruto: Shippuuden Movie 2 - Kizuna
# genre: Action, Martial Arts, Shounen, Supernatural
# -----------------------------------------------
# -----------------------------------------------
# id: 24
# name: School Rumble
# genre: Comedy, Romance, School, Shounen
# -----------------------------------------------
# similarity rank 1
# id: 846
# name: School Rumble Ni Gakki
# genre: Comedy, Romance, School, Shounen
# similarity rank 2
# id: 517
# name: School Rumble Ichi Gakki Hoshuu
# genre: Comedy, Romance, School, Shounen
# similarity rank 3
# id: 4015
# name: School Rumble San Gakki
# genre: Comedy, Romance, School, Shounen
# similarity rank 4
# id: 72
# name: Full Metal Panic? Fumoffu
# genre: Action, Comedy, School
# similarity rank 5
# id: 849
# name: Suzumiya Haruhi no Yuuutsu
# genre: Comedy, Mystery, Parody, School, Sci-Fi, Slice of Life
# similarity rank 6
# id: 71
# name: Full Metal Panic!
# genre: Action, Comedy, Mecha, Military, Sci-Fi
# similarity rank 7
# id: 189
# name: Love Hina
# genre: Comedy, Ecchi, Harem, Romance, Shounen, Slice of Life
# similarity rank 8
# id: 73
# name: Full Metal Panic! The Second Raid
# genre: Action, Mecha, Military
# similarity rank 9
# id: 245
# name: Great Teacher Onizuka
# genre: Comedy, Drama, School, Shounen, Slice of Life
# similarity rank 10
# id: 2104
# name: Seto no Hanayome
# genre: Comedy, Parody, Romance, School
# similarity rank 11
# id: 66
# name: Azumanga Daioh
# genre: Comedy, School, Slice of Life
# similarity rank 12
# id: 4224
# name: Toradora!
# genre: Comedy, Romance, School, Slice of Life
# similarity rank 13
# id: 1887
# name: Lucky☆Star
# genre: Comedy, Parody, School, Slice of Life
# similarity rank 14
# id: 2167
# name: Clannad
# genre: Comedy, Drama, Romance, School, Slice of Life, Supernatural
# similarity rank 15
# id: 59
# name: Chobits
# genre: Comedy, Drama, Ecchi, Romance, Sci-Fi, Seinen
# similarity rank 16
# id: 1210
# name: NHK ni Youkoso!
# genre: Comedy, Drama, Psychological, Romance
# similarity rank 17
# id: 355
# name: Shakugan no Shana
# genre: Action, Drama, Fantasy, Romance, School, Supernatural
# similarity rank 18
# id: 240
# name: Genshiken
# genre: Comedy, Parody, Slice of Life
# similarity rank 19
# id: 330
# name: Midori no Hibi
# genre: Comedy, Drama, Ecchi, Romance, Shounen
# -----------------------------------------------
# -----------------------------------------------
# id: 79
# name: Shuffle!
# genre: Comedy, Drama, Ecchi, Fantasy, Harem, Magic, Romance, School, Seinen
# -----------------------------------------------
# similarity rank 1
# id: 1836
# name: Shuffle! Memories
# genre: Comedy, Drama, Ecchi, Fantasy, Harem, Magic, Romance, School, Seinen
# similarity rank 2
# id: 2993
# name: Rosario to Vampire
# genre: Comedy, Ecchi, Fantasy, Harem, Romance, School, Shounen, Vampire
# similarity rank 3
# id: 4063
# name: Sekirei
# genre: Action, Comedy, Ecchi, Harem, Super Power
# similarity rank 4
# id: 4214
# name: Rosario to Vampire Capu2
# genre: Comedy, Ecchi, Fantasy, Harem, Romance, School, Vampire
# similarity rank 5
# id: 1195
# name: Zero no Tsukaima
# genre: Action, Adventure, Comedy, Ecchi, Fantasy, Harem, Magic, Romance, School
# similarity rank 6
# id: 3503
# name: Kanokon
# genre: Comedy, Ecchi, Harem, Romance, School, Shounen, Slice of Life, Supernatural
# similarity rank 7
# id: 355
# name: Shakugan no Shana
# genre: Action, Drama, Fantasy, Romance, School, Supernatural
# similarity rank 8
# id: 1840
# name: Zero no Tsukaima: Futatsuki no Kishi
# genre: Action, Adventure, Comedy, Ecchi, Fantasy, Harem, Magic, Romance, School
# similarity rank 9
# id: 241
# name: Girls Bravo: First Season
# genre: Comedy, Ecchi, Fantasy, Harem, Romance, School
# similarity rank 10
# id: 63
# name: DearS
# genre: Comedy, Ecchi, Harem, Romance, Sci-Fi
# similarity rank 11
# id: 7088
# name: Ichiban Ushiro no Daimaou
# genre: Action, Comedy, Ecchi, Fantasy, Harem, Magic, School, Shounen
# similarity rank 12
# id: 4744
# name: Akaneiro ni Somaru Saka
# genre: Comedy, Harem, Romance, School
# similarity rank 13
# id: 3455
# name: To LOVE-Ru
# genre: Comedy, Ecchi, Harem, Romance, School, Sci-Fi
# similarity rank 14
# id: 4999
# name: Asu no Yoichi!
# genre: Comedy, Ecchi, Harem, Martial Arts, Romance, Shounen
# similarity rank 15
# id: 2167
# name: Clannad
# genre: Comedy, Drama, Romance, School, Slice of Life, Supernatural
# similarity rank 16
# id: 1530
# name: Kanon (2006)
# genre: Drama, Romance, Slice of Life, Supernatural
# similarity rank 17
# id: 3712
# name: Zero no Tsukaima: Princesses no Rondo
# genre: Action, Adventure, Comedy, Ecchi, Fantasy, Harem, Magic, Romance, School
# similarity rank 18
# id: 193
# name: Maburaho
# genre: Comedy, Drama, Ecchi, Harem, Magic, Romance, School
# similarity rank 19
# id: 6201
# name: Princess Lover!
# genre: Comedy, Ecchi, Harem, School
# -----------------------------------------------

# %%
def get_sorted_by_values(items_id,
                         item_id_to_similar,
                         nb_reco):   
    score = {}

    for item_id in items_id:
        for sim_results in item_id_to_similar[item_id]:
            score[sim_results[0]] = score.get(sim_results[0], 0) + sim_results[1]
  
    # order the dictionary to identify the most similar animes
    sorted_by_value = sorted(score.items(), key=lambda kv: kv[1], reverse=True)
    return sorted_by_value

# %%
sorted_by_value = get_sorted_by_values(items_id=items_id[:10],
                     item_id_to_similar=item_id_to_similar,
                     nb_reco=5
                    )

# %%
sorted_by_value
# Out:
# [(2167, 2.3156978461146482),
#  (849, 2.0325746135802),
#  (1575, 1.8885540696973904),
#  (2904, 1.8177595300839928),
#  (71, 1.5576582947150237),
#  (2993, 1.5442268392669776),
#  (1535, 1.5390210307366161),
#  (4224, 1.5233347128868662),
#  (355, 1.4863803928657444),
#  (1195, 1.4105008357372606),
#  (121, 1.36489436779453),
#  (1840, 1.3551769941647944),
#  (6547, 1.31992002418816),
#  (189, 1.2961200724776685),
#  (2104, 1.2778705067819276),
#  (2787, 1.274857830821524),
#  (241, 1.2681767908338972),
#  (936, 1.2480835800795482),
#  (517, 1.2416125115452403),
#  (4015, 1.2071200439596856),
#  (63, 1.1594826395314328),
#  (4063, 1.1269144964601503),
#  (3503, 1.1159614524091648),
#  (193, 1.1111223068468812),
#  (2472, 1.1108649983300316),
#  (4214, 1.0756935378681154),
#  (4437, 1.0318120453990582),
#  (3455, 0.9937313515791661),
#  (8074, 0.9477430864983402),
#  (11757, 0.9247509018331403),
#  (4654, 0.9207929490478863),
#  (16498, 0.9069332750558332),
#  (5114, 0.9026534379363684),
#  (1818, 0.893809551117522),
#  (3712, 0.8824795308643508),
#  (487, 0.8752992185424079),
#  (226, 0.8721787624446135),
#  (846, 0.8247128890929168),
#  (24, 0.8247128890929168),
#  (2144, 0.7962538238075549),
#  (79, 0.7530897759685207),
#  (72, 0.7393490216917027),
#  (2494, 0.6991338596616942),
#  (73, 0.6797529964935289),
#  (133, 0.6673267916425578),
#  (591, 0.6596719120970962),
#  (245, 0.6493311469346198),
#  (886, 0.6299432615031924),
#  (195, 0.626388631382697),
#  (1722, 0.61733455246945),
#  (1210, 0.6173067736320874),
#  (1887, 0.616176160924544),
#  (240, 0.6159368955114202),
#  (3229, 0.6142145523017527),
#  (6773, 0.6048910891457975),
#  (330, 0.6045419242804977),
#  (6325, 0.5720720481226614),
#  (10087, 0.5435348861790186),
#  (594, 0.5409632045873186),
#  (2248, 0.5363787374633113),
#  (6922, 0.5191382298520115),
#  (761, 0.5170167074105674),
#  (11741, 0.509177374505067),
#  (8246, 0.5077348245058891),
#  (376, 0.4972788336134989),
#  (1074, 0.4911715987189556),
#  (10620, 0.48129407762190024),
#  (356, 0.47654417040432784),
#  (11111, 0.4688780522682304),
#  (269, 0.466974610783123),
#  (934, 0.4649234618762868),
#  (6880, 0.4603569648503151),
#  (10589, 0.4551997057287095),
#  (813, 0.452006430364823),
#  (270, 0.45191872575518394),
#  (442, 0.4444997099847257),
#  (20, 0.4444997099847257),
#  (9919, 0.4439122675141474),
#  (2025, 0.43973546766683363),
#  (1836, 0.43697525188165215),
#  (1815, 0.4347044649536789),
#  (3588, 0.432832107642108),
#  (6572, 0.4288746566269179),
#  (1691, 0.4271060821839673),
#  (223, 0.41795363534614516),
#  (6702, 0.4084388192008567),
#  (8937, 0.4055238898878395),
#  (1686, 0.4044665910923838),
#  (13667, 0.39368640001084826),
#  (7088, 0.3841106544013489),
#  (4744, 0.3816609930272656),
#  (4134, 0.38143448860716633),
#  (2889, 0.3805569814601081),
#  (4999, 0.37537401013876015),
#  (1530, 0.3727655690558144),
#  (6201, 0.3709634369282199),
#  (10686, 0.3647051336025185),
#  (4835, 0.347311287929097),
#  (10659, 0.34083712996191873),
#  (66, 0.32871673370836213),
#  (59, 0.3200087242978359),
#  (248, 0.3186074688914051),
#  (196, 0.3036054959537434),
#  (2963, 0.29820444791228345),
#  (2026, 0.28796018372854487)]

# %%
def user_to_visited_item_id_dict(train,
                                 user_list):
    return train.groupby('user_id')['item_id'].apply(lambda g: g.values
                                                  .tolist()).to_dict()

# %%
user_to_visited_item_id_dict = user_to_visited_item_id_dict(train=train,
                                                            user_list=train.user_id.unique().tolist())

# %%
def print_visited_item(user_id):
    visited_item_list = user_to_visited_item_id_dict[user_id]
    print(f"For user_id: {user_id}, visited animes (count:{len(visited_item_list)}) are:")
    for counter, item_id in enumerate(visited_item_list):
        print(f"visited anime {counter+1}")
        print_item_features(item_id=item_id)

# %%
print_visited_item(user_id=train.user_id.values[0])
# Out:
# For user_id: 1, visited animes (count:153) are:
# visited anime 1
# id: 20
# name: Naruto
# genre: Action, Comedy, Martial Arts, Shounen, Super Power
# visited anime 2
# id: 24
# name: School Rumble
# genre: Comedy, Romance, School, Shounen
# visited anime 3
# id: 79
# name: Shuffle!
# genre: Comedy, Drama, Ecchi, Fantasy, Harem, Magic, Romance, School, Seinen
# visited anime 4
# id: 226
# name: Elfen Lied
# genre: Action, Drama, Horror, Psychological, Romance, Seinen, Supernatural
# visited anime 5
# id: 241
# name: Girls Bravo: First Season
# genre: Comedy, Ecchi, Fantasy, Harem, Romance, School
# visited anime 6
# id: 355
# name: Shakugan no Shana
# genre: Action, Drama, Fantasy, Romance, School, Supernatural
# visited anime 7
# id: 356
# name: Fate/stay night
# genre: Action, Fantasy, Magic, Romance, Supernatural
# visited anime 8
# id: 442
# name: Naruto Movie 1: Dai Katsugeki!! Yuki Hime Shinobu Houjou Dattebayo!
# genre: Adventure, Comedy, Drama, Historical, Shounen, Supernatural
# visited anime 9
# id: 487
# name: Girls Bravo: Second Season
# genre: Comedy, Ecchi, Fantasy, Harem, Romance, School
# visited anime 10
# id: 846
# name: School Rumble Ni Gakki
# genre: Comedy, Romance, School, Shounen
# visited anime 11
# id: 936
# name: Naruto Movie 2: Dai Gekitotsu! Maboroshi no Chiteiiseki Dattebayo!
# genre: Adventure, Comedy, Drama, Fantasy, Shounen, Supernatural
# visited anime 12
# id: 1546
# name: Negima!?
# genre: Adventure, Comedy, Ecchi, Fantasy, Harem, Magic, Romance, School, Supernatural
# visited anime 13
# id: 1692
# name: _Summer
# genre: Drama, Harem, Romance
# visited anime 14
# id: 1836
# name: Shuffle! Memories
# genre: Comedy, Drama, Ecchi, Fantasy, Harem, Magic, Romance, School, Seinen
# visited anime 15
# id: 2001
# name: Tengen Toppa Gurren Lagann
# genre: Action, Adventure, Comedy, Mecha, Sci-Fi
# visited anime 16
# id: 2025
# name: Darker than Black: Kuro no Keiyakusha
# genre: Action, Mystery, Sci-Fi, Super Power
# visited anime 17
# id: 2144
# name: Naruto Movie 3: Dai Koufun! Mikazuki Jima no Animaru Panikku Dattebayo!
# genre: Action, Adventure
# visited anime 18
# id: 2787
# name: Shakugan no Shana II (Second)
# genre: Action, Drama, Fantasy, Romance, School, Supernatural
# visited anime 19
# id: 2993
# name: Rosario to Vampire
# genre: Comedy, Ecchi, Fantasy, Harem, Romance, School, Shounen, Vampire
# visited anime 20
# id: 3455
# name: To LOVE-Ru
# genre: Comedy, Ecchi, Harem, Romance, School, Sci-Fi
# visited anime 21
# id: 4063
# name: Sekirei
# genre: Action, Comedy, Ecchi, Harem, Super Power
# visited anime 22
# id: 4214
# name: Rosario to Vampire Capu2
# genre: Comedy, Ecchi, Fantasy, Harem, Romance, School, Vampire
# visited anime 23
# id: 4224
# name: Toradora!
# genre: Comedy, Romance, School, Slice of Life
# visited anime 24
# id: 4581
# name: Shikabane Hime: Aka
# genre: Action, Horror, Martial Arts
# visited anime 25
# id: 4744
# name: Akaneiro ni Somaru Saka
# genre: Comedy, Harem, Romance, School
# visited anime 26
# id: 4898
# name: Kuroshitsuji
# genre: Action, Comedy, Demons, Fantasy, Historical, Shounen, Supernatural
# visited anime 27
# id: 4999
# name: Asu no Yoichi!
# genre: Comedy, Ecchi, Harem, Martial Arts, Romance, Shounen
# visited anime 28
# id: 5034
# name: Shikabane Hime: Kuro
# genre: Action, Horror
# visited anime 29
# id: 5277
# name: Sekirei: Pure Engagement
# genre: Action, Comedy, Ecchi, Harem, Super Power
# visited anime 30
# id: 5667
# name: To LOVE-Ru OVA
# genre: Comedy, Ecchi, Harem, School, Sci-Fi, Shounen
# visited anime 31
# id: 5781
# name: Isekai no Seikishi Monogatari
# genre: Action, Comedy, Ecchi, Fantasy, Harem, Mecha, School
# visited anime 32
# id: 5958
# name: Sora no Otoshimono
# genre: Comedy, Ecchi, Harem, Romance, Sci-Fi, Shounen, Supernatural
# visited anime 33
# id: 6163
# name: Kuroshitsuji Recap
# genre: Action, Demons, Fantasy, Shounen, Supernatural
# visited anime 34
# id: 6205
# name: Kämpfer
# genre: Action, Comedy, Ecchi, Romance, School, Shoujo Ai, Super Power
# visited anime 35
# id: 6324
# name: Omamori Himari
# genre: Action, Comedy, Demons, Ecchi, Harem, Romance, Supernatural
# visited anime 36
# id: 6500
# name: Seikon no Qwaser
# genre: Action, Ecchi, Seinen, Super Power, Supernatural
# visited anime 37
# id: 6547
# name: Angel Beats!
# genre: Action, Comedy, Drama, School, Supernatural
# visited anime 38
# id: 6682
# name: 11eyes
# genre: Action, Ecchi, Super Power, Supernatural
# visited anime 39
# id: 6707
# name: Kuroshitsuji II
# genre: Action, Comedy, Demons, Fantasy, Shounen, Supernatural
# visited anime 40
# id: 6747
# name: Dance in the Vampire Bund
# genre: Action, Supernatural, Vampire
# visited anime 41
# id: 6773
# name: Shakugan no Shana III (Final)
# genre: Action, Drama, Fantasy, Romance, Supernatural
# visited anime 42
# id: 6793
# name: Kuroshitsuji Special
# genre: Comedy, Demons, Parody
# visited anime 43
# id: 7088
# name: Ichiban Ushiro no Daimaou
# genre: Action, Comedy, Ecchi, Fantasy, Harem, Magic, School, Shounen
# visited anime 44
# id: 7148
# name: Ladies versus Butlers!
# genre: Comedy, Ecchi, Harem, Romance, School, Seinen
# visited anime 45
# id: 7593
# name: Kiss x Sis (TV)
# genre: Comedy, Ecchi, Harem, Romance, School, Seinen
# visited anime 46
# id: 7739
# name: 11eyes: Momoiro Genmutan
# genre: Comedy, Ecchi, Super Power, Supernatural
# visited anime 47
# id: 7858
# name: Sora no Otoshimono: Project Pink
# genre: Comedy, Ecchi, Harem, Sci-Fi, Shounen, Supernatural
# visited anime 48
# id: 8074
# name: Highschool of the Dead
# genre: Action, Ecchi, Horror, Supernatural
# visited anime 49
# id: 8407
# name: Sora no Otoshimono: Forte
# genre: Comedy, Ecchi, Harem, Romance, Sci-Fi, Shounen, Supernatural
# visited anime 50
# id: 8424
# name: MM!
# genre: Comedy, Ecchi, Harem, School
# visited anime 51
# id: 8525
# name: Kami nomi zo Shiru Sekai
# genre: Comedy, Harem, Romance, Shounen, Supernatural
# visited anime 52
# id: 8630
# name: Hidan no Aria
# genre: Action, Comedy, Romance, School
# visited anime 53
# id: 8841
# name: Kore wa Zombie Desu ka?
# genre: Action, Comedy, Ecchi, Harem, Magic, Supernatural
# visited anime 54
# id: 9041
# name: IS: Infinite Stratos
# genre: Action, Comedy, Harem, Mecha, Sci-Fi
# visited anime 55
# id: 9062
# name: Angel Beats! Specials
# genre: Action, Comedy, School, Supernatural
# visited anime 56
# id: 9136
# name: Kuroshitsuji II Specials
# genre: Comedy, Fantasy, Parody, Shounen, Supernatural
# visited anime 57
# id: 9181
# name: Motto To LOVE-Ru
# genre: Comedy, Ecchi, Harem, School, Sci-Fi, Shounen
# visited anime 58
# id: 9330
# name: Dragon Crisis!
# genre: Action, Magic, Romance, School, Seinen, Supernatural
# visited anime 59
# id: 9367
# name: Freezing
# genre: Action, Drama, Ecchi, Harem, Martial Arts, Romance, Sci-Fi, Seinen
# visited anime 60
# id: 9515
# name: Highschool of the Dead: Drifters of the Dead
# genre: Comedy, Ecchi, Supernatural
# visited anime 61
# id: 9581
# name: MM! Specials
# genre: Comedy, Ecchi, School
# visited anime 62
# id: 9675
# name: Kami nomi zo Shiru Sekai: Flag 0
# genre: Comedy, Shounen, Supernatural
# visited anime 63
# id: 9750
# name: Itsuka Tenma no Kuro Usagi
# genre: Comedy, Ecchi, Romance, Shounen, Supernatural, Vampire
# visited anime 64
# id: 9790
# name: Sora no Otoshimono: Tokeijikake no Angeloid
# genre: Comedy, Drama, Ecchi, Harem, Romance, Sci-Fi, Shounen, Supernatural
# visited anime 65
# id: 9919
# name: Ao no Exorcist
# genre: Action, Demons, Fantasy, Shounen, Supernatural
# visited anime 66
# id: 10067
# name: Angel Beats!: Another Epilogue
# genre: Drama, School, Supernatural
# visited anime 67
# id: 10073
# name: Seikon no Qwaser II
# genre: Action, Ecchi, Seinen, Super Power, Supernatural
# visited anime 68
# id: 10076
# name: Kämpfer für die Liebe
# genre: Action, Comedy, Ecchi, Shoujo Ai, Super Power
# visited anime 69
# id: 10079
# name: Hoshizora e Kakaru Hashi
# genre: Comedy, Ecchi, Harem, Romance, School
# visited anime 70
# id: 10080
# name: Kami nomi zo Shiru Sekai II
# genre: Comedy, Harem, Romance, Shounen, Supernatural
# visited anime 71
# id: 10209
# name: Kore wa Zombie Desu ka? OVA
# genre: Action, Comedy, Ecchi, Harem, Magic, Supernatural
# visited anime 72
# id: 10578
# name: C³
# genre: Action, Comedy, Ecchi, School, Supernatural
# visited anime 73
# id: 10604
# name: Hidan no Aria Special
# genre: Action, Comedy, Mystery, Romance
# visited anime 74
# id: 10719
# name: Boku wa Tomodachi ga Sukunai
# genre: Comedy, Ecchi, Harem, Romance, School, Seinen, Slice of Life
# visited anime 75
# id: 10790
# name: Kore wa Zombie Desu ka? of the Dead
# genre: Action, Comedy, Ecchi, Harem, Magic, Supernatural
# visited anime 76
# id: 10793
# name: Guilty Crown
# genre: Action, Drama, Sci-Fi, Super Power
# visited anime 77
# id: 10794
# name: IS: Infinite Stratos Encore - Koi ni Kogareru Rokujuusou
# genre: Action, Comedy, Harem, Mecha, Sci-Fi
# visited anime 78
# id: 10805
# name: Kami nomi zo Shiru Sekai: 4-nin to Idol
# genre: Comedy, Music, Shounen, Supernatural
# visited anime 79
# id: 10897
# name: Boku wa Tomodachi ga Sukunai Episode 0
# genre: Comedy, Romance, School, Seinen, Slice of Life
# visited anime 80
# id: 11161
# name: Hoshizora e Kakaru Hashi: Kakaru ka? Gakuensai ni Koi no Hashi
# genre: Comedy, Ecchi, Romance, School
# visited anime 81
# id: 11266
# name: Ao no Exorcist: Kuro no Iede
# genre: Action, Demons, Fantasy, Shounen, Supernatural
# visited anime 82
# id: 11617
# name: High School DxD
# genre: Comedy, Demons, Ecchi, Harem, Romance, School
# visited anime 83
# id: 11737
# name: Ao no Exorcist Movie
# genre: Action, Demons, Fantasy, Shounen, Supernatural
# visited anime 84
# id: 11757
# name: Sword Art Online
# genre: Action, Adventure, Fantasy, Game, Romance
# visited anime 85
# id: 11759
# name: Accel World
# genre: Action, Game, Romance, School, Sci-Fi
# visited anime 86
# id: 11771
# name: Kuroko no Basket
# genre: Comedy, School, Shounen, Sports
# visited anime 87
# id: 12293
# name: Campione!: Matsurowanu Kamigami to Kamigoroshi no Maou
# genre: Comedy, Ecchi, Fantasy, Harem, Magic, Romance
# visited anime 88
# id: 12549
# name: Dakara Boku wa, H ga Dekinai.
# genre: Comedy, Ecchi, Romance, Supernatural
# visited anime 89
# id: 12729
# name: High School DxD OVA
# genre: Comedy, Demons, Ecchi, Romance, School
# visited anime 90
# id: 13357
# name: High School DxD Specials
# genre: Comedy, Demons, Ecchi, Harem, Romance, School
# visited anime 91
# id: 13367
# name: Kono Naka ni Hitori, Imouto ga Iru!
# genre: Comedy, Ecchi, Harem, Mystery, Romance, School, Seinen
# visited anime 92
# id: 13411
# name: Guilty Crown: Lost Christmas
# genre: Action, Drama, Sci-Fi, Super Power
# visited anime 93
# id: 13561
# name: Guilty Crown: 4-koma Gekijou
# genre: Comedy
# visited anime 94
# id: 13663
# name: To LOVE-Ru Darkness
# genre: Comedy, Ecchi, Harem, Romance, School, Sci-Fi, Shounen
# visited anime 95
# id: 13759
# name: Sakurasou no Pet na Kanojo
# genre: Comedy, Drama, Romance, School, Slice of Life
# visited anime 96
# id: 14749
# name: Ore no Kanojo to Osananajimi ga Shuraba Sugiru
# genre: Comedy, Harem, Romance, School
# visited anime 97
# id: 14813
# name: Yahari Ore no Seishun Love Comedy wa Machigatteiru.
# genre: Comedy, Drama, Romance, School
# visited anime 98
# id: 14833
# name: Maoyuu Maou Yuusha
# genre: Adventure, Demons, Fantasy, Historical, Romance
# visited anime 99
# id: 14967
# name: Boku wa Tomodachi ga Sukunai Next
# genre: Comedy, Harem, Romance, School, Seinen, Slice of Life
# visited anime 100
# id: 15117
# name: Kami nomi zo Shiru Sekai: Tenri-hen
# genre: Comedy, Harem, Romance, Shounen, Supernatural
# visited anime 101
# id: 15437
# name: Kore wa Zombie Desu ka? of the Dead OVA
# genre: Action, Comedy, Ecchi, Harem, Magic, Supernatural
# visited anime 102
# id: 15451
# name: High School DxD New
# genre: Action, Comedy, Demons, Ecchi, Harem, Romance, School
# visited anime 103
# id: 15583
# name: Date A Live
# genre: Comedy, Harem, Mecha, Romance, School, Sci-Fi
# visited anime 104
# id: 15609
# name: Kono Naka ni Hitori, Imouto ga Iru!: Ani, Imouto, Koibito
# genre: Comedy, Ecchi, Harem, Romance, School, Seinen
# visited anime 105
# id: 16011
# name: Tokyo Ravens
# genre: Comedy, School, Shounen, Super Power, Supernatural
# visited anime 106
# id: 16498
# name: Shingeki no Kyojin
# genre: Action, Drama, Fantasy, Shounen, Super Power
# visited anime 107
# id: 16706
# name: Kami nomi zo Shiru Sekai: Megami-hen
# genre: Comedy, Harem, Romance, Shounen, Supernatural
# visited anime 108
# id: 17265
# name: Log Horizon
# genre: Action, Adventure, Fantasy, Game, Magic, Shounen
# visited anime 109
# id: 17729
# name: Grisaia no Kajitsu
# genre: Drama, Harem, Psychological, Romance, School
# visited anime 110
# id: 18247
# name: IS: Infinite Stratos 2
# genre: Action, Comedy, Harem, Mecha, Sci-Fi
# visited anime 111
# id: 18277
# name: Strike the Blood
# genre: Action, Ecchi, Fantasy, Harem, School, Shounen, Supernatural, Vampire
# visited anime 112
# id: 18753
# name: Yahari Ore no Seishun Love Comedy wa Machigatteiru. OVA
# genre: Comedy, Romance, School
# visited anime 113
# id: 18897
# name: Nisekoi
# genre: Comedy, Harem, Romance, School, Shounen
# visited anime 114
# id: 19163
# name: Date A Live II
# genre: Comedy, Harem, Mecha, Romance, School, Sci-Fi
# visited anime 115
# id: 19221
# name: Ore no Nounai Sentakushi ga, Gakuen Love Comedy wo Zenryoku de Jama Shiteiru
# genre: Comedy, Romance, School
# visited anime 116
# id: 19285
# name: Shingeki no Kyojin: Ano Hi Kara
# genre: Action, Drama, Fantasy, Shounen, Super Power
# visited anime 117
# id: 19429
# name: Akuma no Riddle
# genre: Action, School, Shoujo Ai
# visited anime 118
# id: 19815
# name: No Game No Life
# genre: Adventure, Comedy, Ecchi, Fantasy, Game, Supernatural
# visited anime 119
# id: 20045
# name: IS: Infinite Stratos 2 - Hitonatsu no Omoide
# genre: Action, Comedy, Harem, Mecha, Sci-Fi
# visited anime 120
# id: 20785
# name: Mahouka Koukou no Rettousei
# genre: Magic, Romance, School, Sci-Fi, Supernatural
# visited anime 121
# id: 20787
# name: Black Bullet
# genre: Action, Mystery, Sci-Fi, Seinen
# visited anime 122
# id: 21033
# name: Seikoku no Dragonar
# genre: Comedy, Ecchi, Fantasy, School
# visited anime 123
# id: 21881
# name: Sword Art Online II
# genre: Action, Adventure, Fantasy, Game, Romance
# visited anime 124
# id: 22147
# name: Amagi Brilliant Park
# genre: Comedy, Magic
# visited anime 125
# id: 22199
# name: Akame ga Kill!
# genre: Action, Adventure, Fantasy
# visited anime 126
# id: 22319
# name: Tokyo Ghoul
# genre: Action, Drama, Horror, Mystery, Psychological, Seinen, Supernatural
# visited anime 127
# id: 22535
# name: Kiseijuu: Sei no Kakuritsu
# genre: Action, Drama, Horror, Psychological, Sci-Fi, Seinen
# visited anime 128
# id: 22547
# name: Blade &amp; Soul
# genre: Action, Adventure, Fantasy, Martial Arts
# visited anime 129
# id: 22663
# name: Seiken Tsukai no World Break
# genre: Action, Fantasy, Harem, Romance, School, Supernatural
# visited anime 130
# id: 22877
# name: Seirei Tsukai no Blade Dance
# genre: Action, Comedy, Ecchi, Fantasy, Harem, Romance, School, Supernatural
# visited anime 131
# id: 23233
# name: Shinmai Maou no Testament
# genre: Action, Demons, Ecchi, Fantasy, Harem, Romance
# visited anime 132
# id: 23321
# name: Log Horizon 2nd Season
# genre: Action, Adventure, Fantasy, Game, Magic, Shounen
# visited anime 133
# id: 23847
# name: Yahari Ore no Seishun Love Comedy wa Machigatteiru. Zoku
# genre: Comedy, Drama, Romance, School
# visited anime 134
# id: 24133
# name: Taimadou Gakuen 35 Shiken Shoutai
# genre: Action, Ecchi, Fantasy, Harem, Military, Romance, Supernatural
# visited anime 135
# id: 24455
# name: Madan no Ou to Vanadis
# genre: Adventure, Ecchi, Fantasy, Harem, Romance
# visited anime 136
# id: 24873
# name: Juuou Mujin no Fafnir
# genre: Fantasy, Harem, Romance, School
# visited anime 137
# id: 25099
# name: Ore ga Ojousama Gakkou ni &quot;Shomin Sample&quot; Toshite Gets♥Sareta Ken
# genre: Comedy, Ecchi, Harem, Romance, School
# visited anime 138
# id: 25157
# name: Trinity Seven
# genre: Action, Comedy, Ecchi, Fantasy, Harem, Magic, Romance, School, Shounen, Supernatural
# visited anime 139
# id: 25159
# name: Inou-Battle wa Nichijou-kei no Naka de
# genre: Comedy, Romance, School, Slice of Life, Supernatural
# visited anime 140
# id: 25283
# name: Kuusen Madoushi Kouhosei no Kyoukan
# genre: Action, Drama, Fantasy, Magic, School
# visited anime 141
# id: 25397
# name: Absolute Duo
# genre: Action, Ecchi, Harem, Romance, School, Supernatural
# visited anime 142
# id: 26243
# name: Owari no Seraph
# genre: Action, Drama, Shounen, Supernatural, Vampire
# visited anime 143
# id: 27775
# name: Plastic Memories
# genre: Drama, Romance, Sci-Fi
# visited anime 144
# id: 27899
# name: Tokyo Ghoul √A
# genre: Action, Drama, Horror, Mystery, Psychological, Seinen, Supernatural
# visited anime 145
# id: 28121
# name: Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka
# genre: Action, Adventure, Comedy, Fantasy, Romance
# visited anime 146
# id: 28677
# name: Yamada-kun to 7-nin no Majo (TV)
# genre: Comedy, Harem, Mystery, Romance, School, Shounen, Supernatural
# visited anime 147
# id: 29093
# name: Grisaia no Meikyuu: Caprice no Mayu 0
# genre: Drama
# visited anime 148
# id: 29095
# name: Grisaia no Rakuen
# genre: Drama, Harem, Psychological, Romance
# visited anime 149
# id: 30015
# name: ReLIFE
# genre: Romance, School, Slice of Life
# visited anime 150
# id: 30296
# name: Rakudai Kishi no Cavalry
# genre: Action, Ecchi, Fantasy, Romance, School
# visited anime 151
# id: 30544
# name: Gakusen Toshi Asterisk
# genre: Action, Comedy, Ecchi, Fantasy, Harem, Romance, School, Sci-Fi, Supernatural
# visited anime 152
# id: 31338
# name: Hundred
# genre: Action, Ecchi, Harem, Mecha, Romance, School, Sci-Fi
# visited anime 153
# id: 31845
# name: Masou Gakuen HxH
# genre: Action, Comedy, Ecchi, Fantasy, Harem, Romance, School, Sci-Fi

# %%
def compute_recommendation(user_id, user_to_visited_item_id_dict, item_id_to_similar, nb_reco=5):
    visited_item_list = user_to_visited_item_id_dict[user_id]
    sorted_by_values = get_sorted_by_values(
        items_id=visited_item_list,
        item_id_to_similar=item_id_to_similar,
        nb_reco=nb_reco
    )
    return [id_score[0] for id_score in sorted_by_values][:nb_reco]

def print_user_recommendation(user_id, user_to_visited_item_id_dict, item_id_to_similar, nb_reco=5):
    recommendation_list = compute_recommendation(
        user_id=user_id, 
        user_to_visited_item_id_dict=user_to_visited_item_id_dict, 
        item_id_to_similar=item_id_to_similar, 
        nb_reco=nb_reco)
    
    for counter, item_id in enumerate(recommendation_list):
        print(f"recommended item {counter+1}")
        print_item_features(item_id=item_id)

# %%
compute_recommendation(
    user_id=train.user_id.values[0],
    user_to_visited_item_id_dict=user_to_visited_item_id_dict,
    item_id_to_similar=item_id_to_similar,
    nb_reco=5)
# Out:
# [9041, 10719, 8841, 11617, 19815]

# %%
print_user_recommendation(
    user_id=train.user_id.values[0],
    user_to_visited_item_id_dict=user_to_visited_item_id_dict,
    item_id_to_similar=item_id_to_similar,
    nb_reco=5)
# Out:
# recommended item 1
# id: 9041
# name: IS: Infinite Stratos
# genre: Action, Comedy, Harem, Mecha, Sci-Fi
# recommended item 2
# id: 10719
# name: Boku wa Tomodachi ga Sukunai
# genre: Comedy, Ecchi, Harem, Romance, School, Seinen, Slice of Life
# recommended item 3
# id: 8841
# name: Kore wa Zombie Desu ka?
# genre: Action, Comedy, Ecchi, Harem, Magic, Supernatural
# recommended item 4
# id: 11617
# name: High School DxD
# genre: Comedy, Demons, Ecchi, Harem, Romance, School
# recommended item 5
# id: 19815
# name: No Game No Life
# genre: Adventure, Comedy, Ecchi, Fantasy, Game, Supernatural

# %%
def print_visited_anime_and_recommendation(
    user_id,
    user_to_visited_item_id_dict=user_to_visited_item_id_dict, 
    item_id_to_similar=item_id_to_similar, 
    nb_reco=5
):
    
    print_visited_item(user_id=user_id)
    
    print_user_recommendation(
        user_id=user_id,
        user_to_visited_item_id_dict=user_to_visited_item_id_dict,
        item_id_to_similar=item_id_to_similar,
        nb_reco=nb_reco
    )


import random
def get_random_user(users):
    return random.choice(users)

# %% [markdown]
# # Recommendation visualization for a random user

# %%
print_visited_anime_and_recommendation(
    user_id=get_random_user(users=train.user_id.unique().tolist())
)
# Out:
# For user_id: 4968, visited animes (count:36) are:
# visited anime 1
# id: 27
# name: Trinity Blood
# genre: Action, Supernatural, Vampire
# visited anime 2
# id: 60
# name: Chrno Crusade
# genre: Action, Demons, Historical, Romance, Supernatural
# visited anime 3
# id: 64
# name: Rozen Maiden
# genre: Action, Comedy, Drama, Magic, Seinen
# visited anime 4
# id: 112
# name: Chou Henshin Cosprayers
# genre: Action, Adventure, Comedy, Ecchi, Fantasy, Magic, Sci-Fi, Super Power
# visited anime 5
# id: 125
# name: Futakoi
# genre: Comedy, Romance, School
# visited anime 6
# id: 133
# name: Green Green
# genre: Comedy, Ecchi, Romance, School, Slice of Life
# visited anime 7
# id: 143
# name: Kannazuki no Miko
# genre: Drama, Magic, Mecha, Romance, Shoujo Ai, Shounen, Supernatural
# visited anime 8
# id: 180
# name: Vandread
# genre: Action, Ecchi, Mecha, Sci-Fi, Shounen, Space
# visited anime 9
# id: 181
# name: Vandread: The Second Stage
# genre: Action, Ecchi, Mecha, Sci-Fi, Shounen, Space
# visited anime 10
# id: 196
# name: Onegai☆Twins
# genre: Comedy, Drama, Harem, School, Sci-Fi
# visited anime 11
# id: 297
# name: Grenadier: Hohoemi no Senshi
# genre: Action, Adventure, Comedy, Ecchi, Shounen
# visited anime 12
# id: 319
# name: Happy World!
# genre: Comedy, Ecchi, Fantasy, Romance
# visited anime 13
# id: 403
# name: Hanaukyou Maid-tai
# genre: Comedy, Ecchi, Harem, Romance
# visited anime 14
# id: 521
# name: Mermaid Melody Pichi Pichi Pitch
# genre: Adventure, Comedy, Magic, Romance, Shoujo
# visited anime 15
# id: 661
# name: Elf-ban Kakyuusei: Anata dake wo Mitsumete...
# genre: Drama, Harem, Romance, School
# visited anime 16
# id: 811
# name: I&#039;&#039;s Pure
# genre: Comedy, Drama, Ecchi, Romance, School
# visited anime 17
# id: 831
# name: Chicchana Yukitsukai Sugar
# genre: Comedy, Fantasy, Slice of Life
# visited anime 18
# id: 850
# name: Gakuen Heaven
# genre: Comedy, Drama, Romance, School, Shounen Ai
# visited anime 19
# id: 853
# name: Ouran Koukou Host Club
# genre: Comedy, Harem, Romance, School, Shoujo
# visited anime 20
# id: 855
# name: Strawberry Panic
# genre: Drama, Romance, School, Shoujo Ai
# visited anime 21
# id: 881
# name: Green Green OVA
# genre: Comedy, Ecchi, Romance, School
# visited anime 22
# id: 934
# name: Higurashi no Naku Koro ni
# genre: Horror, Mystery, Psychological, Supernatural, Thriller
# visited anime 23
# id: 942
# name: Nishi no Yoki Majo: Astraea Testament
# genre: Comedy, Drama, Fantasy, Mystery, Romance
# visited anime 24
# id: 1110
# name: Mermaid Melody Pichi Pichi Pitch Pure
# genre: Adventure, Comedy, Magic, Romance, Shoujo
# visited anime 25
# id: 1195
# name: Zero no Tsukaima
# genre: Action, Adventure, Comedy, Ecchi, Fantasy, Harem, Magic, Romance, School
# visited anime 26
# id: 1225
# name: 3x3 Eyes Seima Densetsu
# genre: Action, Adventure, Demons, Fantasy, Horror, Romance
# visited anime 27
# id: 1532
# name: Suki na Mono wa Suki Dakara Shou ga Nai!!
# genre: Comedy, Drama, Romance, Shoujo, Shounen Ai, Slice of Life
# visited anime 28
# id: 1571
# name: Ghost Hunt
# genre: Comedy, Horror, Mystery, Shoujo, Supernatural
# visited anime 29
# id: 1640
# name: Angel&#039;s Feather
# genre: Drama, Fantasy, Romance, Sci-Fi, Shoujo, Shounen Ai, Supernatural
# visited anime 30
# id: 1734
# name: Ajimu: Kaigan Monogatari
# genre: Comedy, Drama, Romance, School
# visited anime 31
# id: 1810
# name: Kyoushirou to Towa no Sora
# genre: Drama, Magic, Romance, Shounen
# visited anime 32
# id: 2475
# name: 6 Angels
# genre: Action, Sci-Fi
# visited anime 33
# id: 2993
# name: Rosario to Vampire
# genre: Comedy, Ecchi, Fantasy, Harem, Romance, School, Shounen, Vampire
# visited anime 34
# id: 3457
# name: Vampire Knight
# genre: Drama, Mystery, Romance, Shoujo, Supernatural, Vampire
# visited anime 35
# id: 4214
# name: Rosario to Vampire Capu2
# genre: Comedy, Ecchi, Fantasy, Harem, Romance, School, Vampire
# visited anime 36
# id: 4752
# name: Vampire Knight Guilty
# genre: Drama, Mystery, Romance, Shoujo, Supernatural, Vampire
# recommended item 1
# id: 2993
# name: Rosario to Vampire
# genre: Comedy, Ecchi, Fantasy, Harem, Romance, School, Shounen, Vampire
# recommended item 2
# id: 195
# name: Onegai☆Teacher
# genre: Comedy, Drama, Romance, School, Sci-Fi
# recommended item 3
# id: 63
# name: DearS
# genre: Comedy, Ecchi, Harem, Romance, Sci-Fi
# recommended item 4
# id: 226
# name: Elfen Lied
# genre: Action, Drama, Horror, Psychological, Romance, Seinen, Supernatural
# recommended item 5
# id: 241
# name: Girls Bravo: First Season
# genre: Comedy, Ecchi, Fantasy, Harem, Romance, School
